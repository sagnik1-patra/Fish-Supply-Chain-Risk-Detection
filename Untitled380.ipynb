# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# ============================================================
# PATHS
# ============================================================

BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Fish Supply Chain Risk Detection"
DATA_PATH = os.path.join(BASE_DIR, "ExportoffishandfishproductsinTN_0.csv")
GRAPH_DIR = os.path.join(BASE_DIR, "graphs")

os.makedirs(GRAPH_DIR, exist_ok=True)

# ============================================================
# LOAD DATA
# ============================================================

df = pd.read_csv(DATA_PATH)
df.columns = df.columns.str.lower()

numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
df = df[numeric_cols].dropna()

print("✔ Numeric features used:", numeric_cols)

# ============================================================
# SCALING
# ============================================================

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# ============================================================
# TIME SERIES CREATION
# ============================================================

def create_sequences(data, window=5):
    X, y = [], []
    for i in range(len(data) - window):
        X.append(data[i:i + window])
        y.append(np.mean(data[i + window]))
    return np.array(X), np.array(y)

TIME_STEPS = 5
X, y = create_sequences(scaled_data, TIME_STEPS)

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# ============================================================
# LSTM MODEL
# ============================================================

model = Sequential([
    LSTM(64, activation="tanh", input_shape=(X.shape[1], X.shape[2])),
    Dense(1)
])

model.compile(optimizer="adam", loss="mse")

history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
    verbose=1
)

# ============================================================
# PREDICTION
# ============================================================

train_pred = model.predict(X_train).flatten()
test_pred = model.predict(X_test).flatten()

train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))
r2 = r2_score(y_test, test_pred)

# ============================================================
# AIS RISK SCORING
# ============================================================

mean_pred = np.mean(test_pred)
std_pred = np.std(test_pred)
ais_threshold = mean_pred + 2 * std_pred

risk_scores = np.clip(test_pred / ais_threshold, 0, 1)

# ============================================================
# RESULTS DATAFRAME
# ============================================================

results_df = pd.DataFrame({
    "actual": y_test,
    "predicted": test_pred,
    "risk_score": risk_scores
})

results_df.to_csv(
    os.path.join(BASE_DIR, "risk_results.csv"),
    index=False
)

# ============================================================
# 1️⃣ ACCURACY (LOSS) GRAPH
# ============================================================

plt.figure(figsize=(7, 5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Accuracy (Loss Curve)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.savefig(
    os.path.join(GRAPH_DIR, "accuracy_graph.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
plt.close()

# ============================================================
# 2️⃣ COMPARISON GRAPH
# ============================================================

plt.figure(figsize=(8, 5))
plt.plot(y_test, label="Actual", linewidth=2)
plt.plot(test_pred, label="Predicted", linestyle="--")
plt.title("Actual vs Predicted Comparison")
plt.xlabel("Sample Index")
plt.ylabel("Value")
plt.legend()

plt.savefig(
    os.path.join(GRAPH_DIR, "comparison_graph.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
plt.close()

# ============================================================
# 3️⃣ HEATMAP
# ============================================================

plt.figure(figsize=(6, 4))
sns.heatmap(results_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")

plt.savefig(
    os.path.join(GRAPH_DIR, "heatmap.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
plt.close()

# ============================================================
# 4️⃣ RISK SCORE GRAPH
# ============================================================

plt.figure(figsize=(8, 5))
plt.plot(risk_scores, color="red", label="Risk Score")
plt.axhline(0.8, linestyle="--", color="black", label="High Risk Threshold")
plt.title("AIS Risk Score per Route")
plt.xlabel("Route Index")
plt.ylabel("Risk Score")
plt.legend()

plt.savefig(
    os.path.join(GRAPH_DIR, "risk_score_graph.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
plt.close()

# ============================================================
# 5️⃣ RISK DISTRIBUTION GRAPH
# ============================================================

plt.figure(figsize=(7, 5))
sns.histplot(risk_scores, bins=20, kde=True)
plt.title("Risk Score Distribution")
plt.xlabel("Risk Score")
plt.ylabel("Frequency")

plt.savefig(
    os.path.join(GRAPH_DIR, "risk_distribution_graph.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
plt.close()

# ============================================================
# SAVE MODEL FILES
# ============================================================

model.save(os.path.join(BASE_DIR, "fish_supply_chain_lstm.h5"))
joblib.dump(scaler, os.path.join(BASE_DIR, "scaler.pkl"))
joblib.dump(model, os.path.join(BASE_DIR, "model.pkl"))

# ============================================================
# SAVE JSON
# ============================================================

json_data = {
    "train_rmse": float(train_rmse),
    "test_rmse": float(test_rmse),
    "r2_score": float(r2),
    "ais_threshold": float(ais_threshold),
    "total_routes": len(risk_scores),
    "high_risk_routes": int(sum(risk_scores > 0.8))
}

with open(os.path.join(BASE_DIR, "prediction_summary.json"), "w") as f:
    json.dump(json_data, f, indent=4)

# ============================================================
# SAVE YAML
# ============================================================

yaml_data = {
    "model": "LSTM + AIS",
    "time_steps": TIME_STEPS,
    "features_used": numeric_cols,
    "metrics": json_data
}

with open(os.path.join(BASE_DIR, "config.yaml"), "w") as f:
    yaml.dump(yaml_data, f)

# ============================================================
# FINAL STATUS
# ============================================================

print("\n✅ PIPELINE COMPLETED SUCCESSFULLY")
print("📁 All files saved in:", BASE_DIR)
print("📊 Train RMSE:", train_rmse)
print("📊 Test RMSE:", test_rmse)
print("⚠️ AIS Threshold:", ais_threshold)
# Out:
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ✔ Numeric features used: ['quantity (tonnes)', 'value (rs.in lakhs)']
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 3s 3s/step - loss: 0.2146 - val_loss: 0.9288
# Epoch 2/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1994 - val_loss: 0.8856
# Epoch 3/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1848 - val_loss: 0.8436
# Epoch 4/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1707 - val_loss: 0.8027
# Epoch 5/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1573 - val_loss: 0.7626
# Epoch 6/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1443 - val_loss: 0.7232
# Epoch 7/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1318 - val_loss: 0.6846
# Epoch 8/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1197 - val_loss: 0.6465
# Epoch 9/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1080 - val_loss: 0.6091
# Epoch 10/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0968 - val_loss: 0.5721
# Epoch 11/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0859 - val_loss: 0.5357
# Epoch 12/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0756 - val_loss: 0.4998
# Epoch 13/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0657 - val_loss: 0.4644
# Epoch 14/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0562 - val_loss: 0.4295
# Epoch 15/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0473 - val_loss: 0.3951
# Epoch 16/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0390 - val_loss: 0.3614
# Epoch 17/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0313 - val_loss: 0.3284
# Epoch 18/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0243 - val_loss: 0.2963
# Epoch 19/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0181 - val_loss: 0.2652
# Epoch 20/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0128 - val_loss: 0.2354
# Epoch 21/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0084 - val_loss: 0.2071
# Epoch 22/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0051 - val_loss: 0.1807
# Epoch 23/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0029 - val_loss: 0.1564
# Epoch 24/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0018 - val_loss: 0.1348
# Epoch 25/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0017 - val_loss: 0.1161
# Epoch 26/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0026 - val_loss: 0.1006
# Epoch 27/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0040 - val_loss: 0.0886
# Epoch 28/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0057 - val_loss: 0.0800
# Epoch 29/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0073 - val_loss: 0.0745
# Epoch 30/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0085 - val_loss: 0.0719
# Epoch 31/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0090 - val_loss: 0.0718
# Epoch 32/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0089 - val_loss: 0.0738
# Epoch 33/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0083 - val_loss: 0.0776
# Epoch 34/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0073 - val_loss: 0.0830
# Epoch 35/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0061 - val_loss: 0.0895
# Epoch 36/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0049 - val_loss: 0.0969
# Epoch 37/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0038 - val_loss: 0.1048
# Epoch 38/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0029 - val_loss: 0.1131
# Epoch 39/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0022 - val_loss: 0.1213
# Epoch 40/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0017 - val_loss: 0.1292
# Epoch 41/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0015 - val_loss: 0.1366
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 0s 33ms/step
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:1283: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# ✅ PIPELINE COMPLETED SUCCESSFULLY
# 📁 All files saved in: C:\Users\NXTWAVE\Downloads\Fish Supply Chain Risk Detection
# 📊 Train RMSE: 0.17283864476866329
# 📊 Test RMSE: 0.10347099291822814
# ⚠️ AIS Threshold: 1.0115809440612793
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
