# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# ============================================================
# PATHS & PREFIX
# ============================================================

BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Fish Supply Chain Risk Detection"
DATA_PATH = os.path.join(BASE_DIR, "ExportoffishandfishproductsinTN_0.csv")
GRAPH_DIR = os.path.join(BASE_DIR, "pis_graphs")

PREFIX = "pis_"

os.makedirs(GRAPH_DIR, exist_ok=True)

# ============================================================
# LOAD DATA
# ============================================================

df = pd.read_csv(DATA_PATH)
df.columns = df.columns.str.lower()

numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
df = df[numeric_cols].dropna()

print("✔ Numeric features used:", numeric_cols)

# ============================================================
# SCALING
# ============================================================

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# ============================================================
# TIME SERIES CREATION
# ============================================================

def create_sequences(data, window=5):
    X, y = [], []
    for i in range(len(data) - window):
        X.append(data[i:i + window])
        y.append(np.mean(data[i + window]))
    return np.array(X), np.array(y)

TIME_STEPS = 5
X, y = create_sequences(scaled_data, TIME_STEPS)

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# ============================================================
# LSTM MODEL
# ============================================================

model = Sequential([
    LSTM(64, activation="tanh", input_shape=(X.shape[1], X.shape[2])),
    Dense(1)
])

model.compile(optimizer="adam", loss="mse")

history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
    verbose=1
)

# ============================================================
# PREDICTIONS
# ============================================================

test_pred = model.predict(X_test).flatten()

# ============================================================
# PSO – OPTIMIZE AIS THRESHOLD
# ============================================================

def pso_optimize_threshold(predictions, n_particles=20, iterations=30):
    mean = np.mean(predictions)
    std = np.std(predictions)

    # Particle initialization
    particles = np.random.uniform(mean, mean + 3 * std, n_particles)
    velocities = np.random.uniform(-0.1, 0.1, n_particles)

    pbest = particles.copy()
    pbest_scores = np.zeros(n_particles)

    def fitness(th):
        risk = np.clip(predictions / th, 0, 1)
        return np.var(risk)  # maximize separation

    for i in range(n_particles):
        pbest_scores[i] = fitness(particles[i])

    gbest = pbest[np.argmax(pbest_scores)]

    w, c1, c2 = 0.7, 1.5, 1.5

    for _ in range(iterations):
        for i in range(n_particles):
            velocities[i] = (
                w * velocities[i]
                + c1 * np.random.rand() * (pbest[i] - particles[i])
                + c2 * np.random.rand() * (gbest - particles[i])
            )

            particles[i] += velocities[i]

            score = fitness(particles[i])
            if score > pbest_scores[i]:
                pbest[i] = particles[i]
                pbest_scores[i] = score

        gbest = pbest[np.argmax(pbest_scores)]

    return gbest

ais_threshold = pso_optimize_threshold(test_pred)

# ============================================================
# AIS RISK SCORING
# ============================================================

risk_scores = np.clip(test_pred / ais_threshold, 0, 1)

# ============================================================
# RESULTS DATAFRAME
# ============================================================

results_df = pd.DataFrame({
    "actual": y_test,
    "predicted": test_pred,
    "risk_score": risk_scores
})

results_df.to_csv(
    os.path.join(BASE_DIR, PREFIX + "risk_results.csv"),
    index=False
)

# ============================================================
# 1️⃣ ACCURACY GRAPH
# ============================================================

plt.figure(figsize=(7,5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Hybrid AIS + PSO Training Loss")
plt.legend()

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "accuracy_graph.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# 2️⃣ COMPARISON GRAPH
# ============================================================

plt.figure(figsize=(8,5))
plt.plot(y_test, label="Actual")
plt.plot(test_pred, linestyle="--", label="Predicted")
plt.title("Hybrid AIS + PSO: Actual vs Predicted")
plt.legend()

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "comparison_graph.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# 3️⃣ HEATMAP
# ============================================================

plt.figure(figsize=(6,4))
sns.heatmap(results_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Hybrid AIS + PSO Correlation Heatmap")

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "heatmap.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# 4️⃣ RISK SCORE GRAPH
# ============================================================

plt.figure(figsize=(8,5))
plt.plot(risk_scores, color="red", label="Risk Score")
plt.axhline(0.8, linestyle="--", color="black", label="High Risk Threshold")
plt.title("Hybrid AIS + PSO Risk Scores")
plt.legend()

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "risk_score_graph.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# SAVE MODEL FILES
# ============================================================

model.save(os.path.join(BASE_DIR, PREFIX + "lstm_model.h5"))
joblib.dump(scaler, os.path.join(BASE_DIR, PREFIX + "scaler.pkl"))

# ============================================================
# SAVE JSON
# ============================================================

summary = {
    "model": "Hybrid AIS + PSO",
    "ais_threshold": float(ais_threshold),
    "total_routes": len(risk_scores),
    "high_risk_routes": int(sum(risk_scores > 0.8))
}

with open(os.path.join(BASE_DIR, PREFIX + "prediction_summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

# ============================================================
# SAVE YAML
# ============================================================

yaml_data = {
    "model": "Hybrid AIS + PSO",
    "features_used": numeric_cols,
    "time_steps": TIME_STEPS,
    "optimized_threshold": float(ais_threshold)
}

with open(os.path.join(BASE_DIR, PREFIX + "config.yaml"), "w") as f:
    yaml.dump(yaml_data, f)

# ============================================================
# DONE
# ============================================================

print("\n✅ HYBRID AIS + PSO PIPELINE COMPLETED")
print("📁 Saved in:", BASE_DIR)
print("⚠️ Optimized AIS Threshold:", ais_threshold)
# Out:
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ✔ Numeric features used: ['quantity (tonnes)', 'value (rs.in lakhs)']
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 3s 3s/step - loss: 0.2862 - val_loss: 1.1198
# Epoch 2/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2684 - val_loss: 1.0724
# Epoch 3/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2513 - val_loss: 1.0264
# Epoch 4/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2349 - val_loss: 0.9817
# Epoch 5/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2191 - val_loss: 0.9381
# Epoch 6/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2039 - val_loss: 0.8954
# Epoch 7/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1891 - val_loss: 0.8536
# Epoch 8/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1749 - val_loss: 0.8126
# Epoch 9/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1611 - val_loss: 0.7722
# Epoch 10/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1477 - val_loss: 0.7324
# Epoch 11/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1347 - val_loss: 0.6930
# Epoch 12/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1221 - val_loss: 0.6541
# Epoch 13/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1099 - val_loss: 0.6155
# Epoch 14/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0981 - val_loss: 0.5772
# Epoch 15/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0866 - val_loss: 0.5392
# Epoch 16/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0756 - val_loss: 0.5015
# Epoch 17/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0650 - val_loss: 0.4642
# Epoch 18/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0550 - val_loss: 0.4272
# Epoch 19/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0455 - val_loss: 0.3907
# Epoch 20/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0367 - val_loss: 0.3548
# Epoch 21/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0286 - val_loss: 0.3197
# Epoch 22/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0213 - val_loss: 0.2856
# Epoch 23/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0151 - val_loss: 0.2528
# Epoch 24/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0099 - val_loss: 0.2215
# Epoch 25/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0059 - val_loss: 0.1923
# Epoch 26/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0032 - val_loss: 0.1655
# Epoch 27/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0018 - val_loss: 0.1415
# Epoch 28/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0016 - val_loss: 0.1207
# Epoch 29/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0026 - val_loss: 0.1036
# Epoch 30/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0043 - val_loss: 0.0902
# Epoch 31/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0064 - val_loss: 0.0806
# Epoch 32/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0083 - val_loss: 0.0746
# Epoch 33/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0098 - val_loss: 0.0716
# Epoch 34/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0105 - val_loss: 0.0715
# Epoch 35/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0104 - val_loss: 0.0737
# Epoch 36/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0097 - val_loss: 0.0780
# Epoch 37/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0085 - val_loss: 0.0840
# Epoch 38/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0071 - val_loss: 0.0914
# Epoch 39/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0056 - val_loss: 0.0998
# Epoch 40/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0042 - val_loss: 0.1088
# Epoch 41/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0031 - val_loss: 0.1182
# Epoch 42/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0023 - val_loss: 0.1276
# Epoch 43/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0017 - val_loss: 0.1367
# Epoch 44/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0014 - val_loss: 0.1452
# 1/1 [==============================] - 0s 440ms/step
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# ✅ HYBRID AIS + PSO PIPELINE COMPLETED
# 📁 Saved in: C:\Users\NXTWAVE\Downloads\Fish Supply Chain Risk Detection
# ⚠️ Optimized AIS Threshold: 1.0120068788528442
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
