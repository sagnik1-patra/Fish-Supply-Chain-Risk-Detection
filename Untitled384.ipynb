# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# ============================================================
# PATHS & PREFIX
# ============================================================

BASE_DIR = r"C:\Users\NXTWAVE\Downloads\Fish Supply Chain Risk Detection"
DATA_PATH = os.path.join(BASE_DIR, "ExportoffishandfishproductsinTN_0.csv")
GRAPH_DIR = os.path.join(BASE_DIR, "bis_graphs")

PREFIX = "bis_"
os.makedirs(GRAPH_DIR, exist_ok=True)

# ============================================================
# LOAD DATA
# ============================================================

df = pd.read_csv(DATA_PATH)
df.columns = df.columns.str.lower()

numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
df = df[numeric_cols].dropna()

print("✔ Numeric features used:", numeric_cols)

# ============================================================
# SCALING
# ============================================================

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# ============================================================
# TIME SERIES CREATION
# ============================================================

def create_sequences(data, window=5):
    X, y = [], []
    for i in range(len(data) - window):
        X.append(data[i:i + window])
        y.append(np.mean(data[i + window]))
    return np.array(X), np.array(y)

TIME_STEPS = 5
X, y = create_sequences(scaled_data, TIME_STEPS)

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# ============================================================
# LSTM MODEL
# ============================================================

model = Sequential([
    LSTM(64, activation="tanh", input_shape=(X.shape[1], X.shape[2])),
    Dense(1)
])

model.compile(optimizer="adam", loss="mse")

history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
    verbose=1
)

# ============================================================
# PREDICTIONS
# ============================================================

test_pred = model.predict(X_test).flatten()

# ============================================================
# BAT ALGORITHM – OPTIMIZE AIS THRESHOLD
# ============================================================

def bat_optimize_threshold(predictions, n_bats=20, iterations=30):
    mean, std = np.mean(predictions), np.std(predictions)
    bats = np.random.uniform(mean, mean + 3 * std, n_bats)
    velocity = np.zeros(n_bats)

    loudness = np.ones(n_bats)
    pulse_rate = np.random.rand(n_bats)

    def fitness(th):
        risk = np.clip(predictions / th, 0, 1)
        return np.var(risk)  # maximize separation

    best = bats[np.argmax([fitness(b) for b in bats])]

    for t in range(iterations):
        for i in range(n_bats):
            freq = np.random.rand()
            velocity[i] += (bats[i] - best) * freq
            bats[i] += velocity[i]

            if np.random.rand() > pulse_rate[i]:
                bats[i] = best + 0.01 * np.random.randn()

            if fitness(bats[i]) > fitness(best) and np.random.rand() < loudness[i]:
                best = bats[i]
                loudness[i] *= 0.9
                pulse_rate[i] *= (1 - np.exp(-0.1 * t))

    return best

ais_threshold = bat_optimize_threshold(test_pred)

# ============================================================
# AIS RISK SCORING
# ============================================================

risk_scores = np.clip(test_pred / ais_threshold, 0, 1)

# ============================================================
# RESULTS CSV
# ============================================================

results_df = pd.DataFrame({
    "actual": y_test,
    "predicted": test_pred,
    "risk_score": risk_scores
})

results_df.to_csv(
    os.path.join(BASE_DIR, PREFIX + "risk_results.csv"),
    index=False
)

# ============================================================
# 1️⃣ ACCURACY GRAPH
# ============================================================

plt.figure(figsize=(7,5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.title("Hybrid BA + AIS Training Loss")

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "accuracy_graph.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# 2️⃣ COMPARISON GRAPH
# ============================================================

plt.figure(figsize=(8,5))
plt.plot(y_test, label="Actual")
plt.plot(test_pred, linestyle="--", label="Predicted")
plt.legend()
plt.title("Hybrid BA + AIS: Actual vs Predicted")

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "comparison_graph.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# 3️⃣ HEATMAP
# ============================================================

plt.figure(figsize=(6,4))
sns.heatmap(results_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Hybrid BA + AIS Correlation Heatmap")

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "heatmap.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# 4️⃣ RISK SCORE GRAPH
# ============================================================

plt.figure(figsize=(8,5))
plt.plot(risk_scores, color="red", label="Risk Score")
plt.axhline(0.8, linestyle="--", color="black", label="High Risk Threshold")
plt.legend()
plt.title("Hybrid BA + AIS Risk Scores")

plt.savefig(os.path.join(GRAPH_DIR, PREFIX + "risk_score_graph.png"),
            dpi=300, bbox_inches="tight")
plt.show()
plt.close()

# ============================================================
# SAVE MODEL FILES
# ============================================================

model.save(os.path.join(BASE_DIR, PREFIX + "lstm_model.h5"))
joblib.dump(scaler, os.path.join(BASE_DIR, PREFIX + "scaler.pkl"))

# ============================================================
# SAVE JSON
# ============================================================

summary = {
    "model": "Hybrid BA + AIS",
    "ais_threshold": float(ais_threshold),
    "total_routes": len(risk_scores),
    "high_risk_routes": int(sum(risk_scores > 0.8))
}

with open(os.path.join(BASE_DIR, PREFIX + "prediction_summary.json"), "w") as f:
    json.dump(summary, f, indent=4)

# ============================================================
# SAVE YAML
# ============================================================

yaml_data = {
    "model": "Hybrid BA + AIS",
    "features_used": numeric_cols,
    "time_steps": TIME_STEPS,
    "optimized_threshold": float(ais_threshold)
}

with open(os.path.join(BASE_DIR, PREFIX + "config.yaml"), "w") as f:
    yaml.dump(yaml_data, f)

# ============================================================
# DONE
# ============================================================

print("\n✅ HYBRID BA + AIS PIPELINE COMPLETED")
print("📁 Saved in:", BASE_DIR)
print("⚠️ Optimized AIS Threshold:", ais_threshold)
# Out:
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ✔ Numeric features used: ['quantity (tonnes)', 'value (rs.in lakhs)']
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 3s 3s/step - loss: 0.2661 - val_loss: 1.0615
# Epoch 2/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2507 - val_loss: 1.0209
# Epoch 3/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.2359 - val_loss: 0.9810
# Epoch 4/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.2214 - val_loss: 0.9418
# Epoch 5/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2074 - val_loss: 0.9032
# Epoch 6/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1937 - val_loss: 0.8651
# Epoch 7/100
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1804 - val_loss: 0.8275
# Epoch 8/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1675 - val_loss: 0.7903
# Epoch 9/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1548 - val_loss: 0.7533
# Epoch 10/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1424 - val_loss: 0.7166
# Epoch 11/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1303 - val_loss: 0.6800
# Epoch 12/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1185 - val_loss: 0.6435
# Epoch 13/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1069 - val_loss: 0.6070
# Epoch 14/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0957 - val_loss: 0.5706
# Epoch 15/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0847 - val_loss: 0.5342
# Epoch 16/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0741 - val_loss: 0.4978
# Epoch 17/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0638 - val_loss: 0.4615
# Epoch 18/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0540 - val_loss: 0.4253
# Epoch 19/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0446 - val_loss: 0.3893
# Epoch 20/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0359 - val_loss: 0.3538
# Epoch 21/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0279 - val_loss: 0.3187
# Epoch 22/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0207 - val_loss: 0.2845
# Epoch 23/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0145 - val_loss: 0.2514
# Epoch 24/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0094 - val_loss: 0.2199
# Epoch 25/100
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0055 - val_loss: 0.1902
# Epoch 26/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0029 - val_loss: 0.1631
# Epoch 27/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 0.1389
# Epoch 28/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0019 - val_loss: 0.1181
# Epoch 29/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0031 - val_loss: 0.1013
# Epoch 30/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0051 - val_loss: 0.0885
# Epoch 31/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0073 - val_loss: 0.0796
# Epoch 32/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0092 - val_loss: 0.0745
# Epoch 33/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0105 - val_loss: 0.0727
# Epoch 34/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0109 - val_loss: 0.0738
# Epoch 35/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0106 - val_loss: 0.0773
# Epoch 36/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0095 - val_loss: 0.0828
# Epoch 37/100
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0081 - val_loss: 0.0901
# Epoch 38/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0065 - val_loss: 0.0987
# Epoch 39/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0050 - val_loss: 0.1082
# Epoch 40/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0037 - val_loss: 0.1182
# Epoch 41/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0027 - val_loss: 0.1283
# Epoch 42/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0020 - val_loss: 0.1383
# Epoch 43/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0016 - val_loss: 0.1477
# 1/1 [==============================] - 0s 435ms/step
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ✅ HYBRID BA + AIS PIPELINE COMPLETED
# 📁 Saved in: C:\Users\NXTWAVE\Downloads\Fish Supply Chain Risk Detection
# ⚠️ Optimized AIS Threshold: 1.0118591785430908
